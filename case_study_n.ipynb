# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
ls data
# Out:
# Data Dictionary.xlsx    Train.csv               test.csv
# Example_Output.csv      Train.zip               ~$Data Dictionary.xlsx
# Test.zip                end_of_day/

# %%
df = pd.read_csv('data/Train.csv')
# Out:
# /Users/nicochen/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (13,39,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
# 4                     722.0    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# 2                     NaN          NaN   NaN             NaN          NaN
# 3                     NaN          NaN   NaN             NaN          NaN
# 4                     NaN          NaN   NaN             NaN          NaN
#
#   Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 0              NaN        NaN             NaN          Standard
# 1              NaN        NaN             NaN          Standard
# 2              NaN        NaN             NaN               NaN
# 3              NaN        NaN             NaN               NaN
# 4              NaN        NaN             NaN               NaN
#
#   Steering_Controls
# 0      Conventional
# 1      Conventional
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 53 columns]

# %%
df2=pd.read_csv('data/test.csv')

# %%
df2
# Out:
#        SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0      1222837     902859     1376         121             3      1000
# 1      1222839    1048320    36526         121             3      2006
# 2      1222841     999308     4587         121             3      2000
# 3      1222843    1062425     1954         121             3      1000
# 4      1222845    1032841     4701         121             3      2002
# ...        ...        ...      ...         ...           ...       ...
# 11568  6333344    1919201    21435         149             2      2005
# 11569  6333345    1882122    21436         149             2      2005
# 11570  6333347    1944213    21435         149             2      2005
# 11571  6333348    1794518    21435         149             2      2006
# 11572  6333349    1944743    21436         149             2      2006
#
#        MachineHoursCurrentMeter UsageBand        saledate fiModelDesc  ...  \
# 0                           0.0       NaN   1/5/2012 0:00        375L  ...
# 1                        4412.0    Medium   1/5/2012 0:00    TX300LC2  ...
# 2                       10127.0    Medium   1/5/2012 0:00       270LC  ...
# 3                        4682.0       Low   1/5/2012 0:00      892DLC  ...
# 4                        8150.0    Medium   1/4/2012 0:00        544H  ...
# ...                         ...       ...             ...         ...  ...
# 11568                       NaN       NaN   3/7/2012 0:00        30NX  ...
# 11569                       NaN       NaN  1/28/2012 0:00       30NX2  ...
# 11570                       NaN       NaN  1/28/2012 0:00        30NX  ...
# 11571                       NaN       NaN   3/7/2012 0:00        30NX  ...
# 11572                       NaN       NaN  1/28/2012 0:00       30NX2  ...
#
#       Undercarriage_Pad_Width         Stick_Length                Thumb  \
# 0         None or Unspecified  None or Unspecified  None or Unspecified
# 1         None or Unspecified               12' 4"  None or Unspecified
# 2         None or Unspecified               12' 4"  None or Unspecified
# 3         None or Unspecified  None or Unspecified  None or Unspecified
# 4                         NaN                  NaN                  NaN
# ...                       ...                  ...                  ...
# 11568     None or Unspecified  None or Unspecified  None or Unspecified
# 11569     None or Unspecified  None or Unspecified  None or Unspecified
# 11570     None or Unspecified  None or Unspecified  None or Unspecified
# 11571     None or Unspecified  None or Unspecified  None or Unspecified
# 11572     None or Unspecified  None or Unspecified  None or Unspecified
#
#            Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0      None or Unspecified       Double              NaN        NaN
# 1                      Yes       Double              NaN        NaN
# 2      None or Unspecified       Double              NaN        NaN
# 3      None or Unspecified       Double              NaN        NaN
# 4                      NaN          NaN              NaN        NaN
# ...                    ...          ...              ...        ...
# 11568  None or Unspecified       Double              NaN        NaN
# 11569  None or Unspecified       Double              NaN        NaN
# 11570  None or Unspecified       Double              NaN        NaN
# 11571  None or Unspecified       Double              NaN        NaN
# 11572  None or Unspecified       Double              NaN        NaN
#
#       Travel_Controls Differential_Type Steering_Controls
# 0                 NaN               NaN               NaN
# 1                 NaN               NaN               NaN
# 2                 NaN               NaN               NaN
# 3                 NaN               NaN               NaN
# 4                 NaN          Standard      Conventional
# ...               ...               ...               ...
# 11568             NaN               NaN               NaN
# 11569             NaN               NaN               NaN
# 11570             NaN               NaN               NaN
# 11571             NaN               NaN               NaN
# 11572             NaN               NaN               NaN
#
# [11573 rows x 52 columns]
